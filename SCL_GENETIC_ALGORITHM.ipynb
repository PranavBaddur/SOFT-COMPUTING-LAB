# %%
import numpy as np
import pandas as pd
from IPython.display import display

def fitness(x):
    return np.sum(x**2)

def selection(population, fitness_vals):
    probs = fitness_vals / np.sum(fitness_vals)
    selected = population[np.random.choice(len(population), size=len(population), p=probs)]
    return selected

def crossover(parent1, parent2):
    crossover_point = np.random.randint(1, len(parent1))
    child = np.concatenate((parent1[:crossover_point], parent2[crossover_point:]))
    return child

def mutation(child, mutation_rate):
    for i in range(len(child)):
        if np.random.rand() < mutation_rate:
            child[i] = 1 - child[i]
    return child

def genetic_algorithm(pop_size, gen_size, mutation_rate, chrom_length):
    population = np.random.randint(0, 2, size=(pop_size, chrom_length))
    fitness_vals = np.array([fitness(ind) for ind in population])
    data = []

    for gen in range(gen_size):
        selected = selection(population, fitness_vals)
        next_generation = []

        for i in range(0, pop_size, 2):
            parent1, parent2 = selected[i], selected[i + 1]
            child1, child2 = crossover(parent1, parent2), crossover(parent2, parent1)
            next_generation.append(mutation(child1, mutation_rate))
            next_generation.append(mutation(child2, mutation_rate))

        population = np.array(next_generation)
        fitness_vals = np.array([fitness(ind) for ind in population])

        data.append([gen, np.min(fitness_vals), np.max(fitness_vals), np.mean(fitness_vals)])

        print(f"Generation {gen}: Min Fitness = {np.min(fitness_vals)}, Max Fitness = {np.max(fitness_vals)}, Avg Fitness = {np.mean(fitness_vals)}")

    df = pd.DataFrame(data, columns=["Generation", "Min Fitness", "Max Fitness", "Avg Fitness"])
    styled_df = df.style.format({
        "Min Fitness": "{:.2f}",
        "Max Fitness": "{:.2f}",
        "Avg Fitness": "{:.2f}"
    }).background_gradient(cmap="viridis", axis=0).set_table_styles(
        [{'selector': 'thead th', 'props': [('background-color', '#4CAF50'), ('color', 'white')]},
         {'selector': 'tbody td', 'props': [('background-color', '#f9f9f9'), ('color', 'black')]},
         {'selector': 'tbody tr:nth-child(even)', 'props': [('background-color', '#f1f1f1')]},
         {'selector': 'tbody tr:hover', 'props': [('background-color', '#e2e2e2')]}]
    )

    display(styled_df)
    return df

df = genetic_algorithm(10, 50, 0.05, 10)
# Out:
# Generation 0: Min Fitness = 4, Max Fitness = 7, Avg Fitness = 5.4
# Generation 1: Min Fitness = 4, Max Fitness = 9, Avg Fitness = 6.5
# Generation 2: Min Fitness = 4, Max Fitness = 10, Avg Fitness = 6.3
# Generation 3: Min Fitness = 4, Max Fitness = 9, Avg Fitness = 6.3
# Generation 4: Min Fitness = 4, Max Fitness = 10, Avg Fitness = 6.3
# Generation 5: Min Fitness = 5, Max Fitness = 9, Avg Fitness = 7.3
# Generation 6: Min Fitness = 6, Max Fitness = 9, Avg Fitness = 7.6
# Generation 7: Min Fitness = 5, Max Fitness = 9, Avg Fitness = 7.1
# Generation 8: Min Fitness = 7, Max Fitness = 9, Avg Fitness = 8.1
# Generation 9: Min Fitness = 7, Max Fitness = 9, Avg Fitness = 7.7
# Generation 10: Min Fitness = 7, Max Fitness = 9, Avg Fitness = 8.3
# Generation 11: Min Fitness = 6, Max Fitness = 9, Avg Fitness = 7.8
# Generation 12: Min Fitness = 7, Max Fitness = 9, Avg Fitness = 7.6
# Generation 13: Min Fitness = 7, Max Fitness = 9, Avg Fitness = 7.9
# Generation 14: Min Fitness = 6, Max Fitness = 10, Avg Fitness = 7.8
# Generation 15: Min Fitness = 7, Max Fitness = 10, Avg Fitness = 8.3
# Generation 16: Min Fitness = 6, Max Fitness = 10, Avg Fitness = 8.4
# Generation 17: Min Fitness = 7, Max Fitness = 10, Avg Fitness = 8.6
# Generation 18: Min Fitness = 6, Max Fitness = 10, Avg Fitness = 8.7
# Generation 19: Min Fitness = 6, Max Fitness = 9, Avg Fitness = 8.1
# Generation 20: Min Fitness = 6, Max Fitness = 9, Avg Fitness = 8.1
# Generation 21: Min Fitness = 6, Max Fitness = 9, Avg Fitness = 7.8
# Generation 22: Min Fitness = 7, Max Fitness = 9, Avg Fitness = 8.3
# Generation 23: Min Fitness = 6, Max Fitness = 10, Avg Fitness = 8.1
# Generation 24: Min Fitness = 4, Max Fitness = 10, Avg Fitness = 8.2
# Generation 25: Min Fitness = 7, Max Fitness = 10, Avg Fitness = 8.2
# Generation 26: Min Fitness = 6, Max Fitness = 10, Avg Fitness = 8.0
# Generation 27: Min Fitness = 6, Max Fitness = 9, Avg Fitness = 7.8
# Generation 28: Min Fitness = 6, Max Fitness = 9, Avg Fitness = 7.8
# Generation 29: Min Fitness = 7, Max Fitness = 9, Avg Fitness = 7.9
# Generation 30: Min Fitness = 5, Max Fitness = 9, Avg Fitness = 7.5
# Generation 31: Min Fitness = 7, Max Fitness = 9, Avg Fitness = 7.7
# Generation 32: Min Fitness = 6, Max Fitness = 9, Avg Fitness = 7.7
# Generation 33: Min Fitness = 7, Max Fitness = 9, Avg Fitness = 7.9
# Generation 34: Min Fitness = 5, Max Fitness = 9, Avg Fitness = 8.0
# Generation 35: Min Fitness = 6, Max Fitness = 9, Avg Fitness = 8.0
# Generation 36: Min Fitness = 6, Max Fitness = 10, Avg Fitness = 8.0
# Generation 37: Min Fitness = 6, Max Fitness = 9, Avg Fitness = 7.6
# Generation 38: Min Fitness = 6, Max Fitness = 9, Avg Fitness = 7.4
# Generation 39: Min Fitness = 6, Max Fitness = 9, Avg Fitness = 7.1
# Generation 40: Min Fitness = 4, Max Fitness = 9, Avg Fitness = 6.4
# Generation 41: Min Fitness = 5, Max Fitness = 8, Avg Fitness = 6.6
# Generation 42: Min Fitness = 5, Max Fitness = 7, Avg Fitness = 6.2
# Generation 43: Min Fitness = 5, Max Fitness = 8, Avg Fitness = 6.2
# Generation 44: Min Fitness = 2, Max Fitness = 7, Avg Fitness = 4.8
# Generation 45: Min Fitness = 3, Max Fitness = 7, Avg Fitness = 5.2
# Generation 46: Min Fitness = 5, Max Fitness = 8, Avg Fitness = 6.3
# Generation 47: Min Fitness = 5, Max Fitness = 7, Avg Fitness = 6.0
# Generation 48: Min Fitness = 5, Max Fitness = 9, Avg Fitness = 6.5
# Generation 49: Min Fitness = 4, Max Fitness = 8, Avg Fitness = 6.4
# <style type="text/css">
# #T_2d05e thead th {
#   background-color: #4CAF50;
#   color: white;
# }
# #T_2d05e tbody td {
#   background-color: #f9f9f9;
#   color: black;
# }
# #T_2d05e tbody tr:nth-child(even) {
#   background-color: #f1f1f1;
# }
# #T_2d05e tbody tr:hover {
#   background-color: #e2e2e2;
# }
# #T_2d05e_row0_col0, #T_2d05e_row0_col2, #T_2d05e_row42_col2, #T_2d05e_row44_col1, #T_2d05e_row44_col2, #T_2d05e_row44_col3, #T_2d05e_row45_col2, #T_2d05e_row47_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_2d05e_row0_col1, #T_2d05e_row1_col1, #T_2d05e_row2_col1, #T_2d05e_row3_col1, #T_2d05e_row4_col1, #T_2d05e_row24_col1, #T_2d05e_row40_col1, #T_2d05e_row49_col1 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_2d05e_row0_col3 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_2d05e_row1_col0 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_2d05e_row1_col2, #T_2d05e_row3_col2, #T_2d05e_row5_col2, #T_2d05e_row6_col2, #T_2d05e_row7_col2, #T_2d05e_row8_col2, #T_2d05e_row9_col2, #T_2d05e_row10_col2, #T_2d05e_row11_col2, #T_2d05e_row12_col2, #T_2d05e_row13_col2, #T_2d05e_row19_col2, #T_2d05e_row20_col2, #T_2d05e_row21_col2, #T_2d05e_row22_col2, #T_2d05e_row27_col2, #T_2d05e_row28_col2, #T_2d05e_row29_col2, #T_2d05e_row30_col2, #T_2d05e_row31_col2, #T_2d05e_row32_col2, #T_2d05e_row33_col2, #T_2d05e_row34_col2, #T_2d05e_row35_col2, #T_2d05e_row37_col2, #T_2d05e_row38_col2, #T_2d05e_row38_col3, #T_2d05e_row39_col2, #T_2d05e_row40_col2, #T_2d05e_row48_col2 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_2d05e_row1_col3, #T_2d05e_row48_col3 {
#   background-color: #26818e;
#   color: #f1f1f1;
# }
# #T_2d05e_row2_col0 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_2d05e_row2_col2, #T_2d05e_row4_col2, #T_2d05e_row8_col1, #T_2d05e_row9_col1, #T_2d05e_row10_col1, #T_2d05e_row12_col1, #T_2d05e_row13_col1, #T_2d05e_row14_col2, #T_2d05e_row15_col1, #T_2d05e_row15_col2, #T_2d05e_row16_col2, #T_2d05e_row17_col1, #T_2d05e_row17_col2, #T_2d05e_row18_col2, #T_2d05e_row18_col3, #T_2d05e_row22_col1, #T_2d05e_row23_col2, #T_2d05e_row24_col2, #T_2d05e_row25_col1, #T_2d05e_row25_col2, #T_2d05e_row26_col2, #T_2d05e_row29_col1, #T_2d05e_row31_col1, #T_2d05e_row33_col1, #T_2d05e_row36_col2, #T_2d05e_row49_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_2d05e_row2_col3, #T_2d05e_row3_col3, #T_2d05e_row4_col3, #T_2d05e_row46_col3 {
#   background-color: #2b748e;
#   color: #f1f1f1;
# }
# #T_2d05e_row3_col0 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_2d05e_row4_col0 {
#   background-color: #481d6f;
#   color: #f1f1f1;
# }
# #T_2d05e_row5_col0, #T_2d05e_row45_col3 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_2d05e_row5_col1, #T_2d05e_row7_col1, #T_2d05e_row30_col1, #T_2d05e_row34_col1, #T_2d05e_row41_col1, #T_2d05e_row42_col1, #T_2d05e_row43_col1, #T_2d05e_row46_col1, #T_2d05e_row47_col1, #T_2d05e_row48_col1 {
#   background-color: #22a884;
#   color: #f1f1f1;
# }
# #T_2d05e_row5_col3 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_2d05e_row6_col0 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_2d05e_row6_col1, #T_2d05e_row11_col1, #T_2d05e_row14_col1, #T_2d05e_row16_col1, #T_2d05e_row18_col1, #T_2d05e_row19_col1, #T_2d05e_row20_col1, #T_2d05e_row21_col1, #T_2d05e_row23_col1, #T_2d05e_row26_col1, #T_2d05e_row27_col1, #T_2d05e_row28_col1, #T_2d05e_row32_col1, #T_2d05e_row35_col1, #T_2d05e_row36_col1, #T_2d05e_row37_col1, #T_2d05e_row38_col1, #T_2d05e_row39_col1 {
#   background-color: #7ad151;
#   color: #000000;
# }
# #T_2d05e_row6_col3, #T_2d05e_row12_col3, #T_2d05e_row37_col3 {
#   background-color: #4cc26c;
#   color: #000000;
# }
# #T_2d05e_row7_col0 {
#   background-color: #46327e;
#   color: #f1f1f1;
# }
# #T_2d05e_row7_col3, #T_2d05e_row39_col3 {
#   background-color: #21a585;
#   color: #f1f1f1;
# }
# #T_2d05e_row8_col0 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_2d05e_row8_col3, #T_2d05e_row19_col3, #T_2d05e_row20_col3, #T_2d05e_row23_col3 {
#   background-color: #98d83e;
#   color: #000000;
# }
# #T_2d05e_row9_col0 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_2d05e_row9_col3, #T_2d05e_row31_col3, #T_2d05e_row32_col3 {
#   background-color: #5ac864;
#   color: #000000;
# }
# #T_2d05e_row10_col0 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_2d05e_row10_col3, #T_2d05e_row15_col3, #T_2d05e_row22_col3, #T_2d05e_row44_col0 {
#   background-color: #bade28;
#   color: #000000;
# }
# #T_2d05e_row11_col0 {
#   background-color: #3e4a89;
#   color: #f1f1f1;
# }
# #T_2d05e_row11_col3, #T_2d05e_row14_col3, #T_2d05e_row21_col3, #T_2d05e_row27_col3, #T_2d05e_row28_col3 {
#   background-color: #67cc5c;
#   color: #000000;
# }
# #T_2d05e_row12_col0 {
#   background-color: #3c508b;
#   color: #f1f1f1;
# }
# #T_2d05e_row13_col0 {
#   background-color: #39558c;
#   color: #f1f1f1;
# }
# #T_2d05e_row13_col3, #T_2d05e_row29_col3, #T_2d05e_row33_col3, #T_2d05e_row39_col0 {
#   background-color: #77d153;
#   color: #000000;
# }
# #T_2d05e_row14_col0 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_2d05e_row15_col0, #T_2d05e_row47_col3 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_2d05e_row16_col0 {
#   background-color: #31668e;
#   color: #f1f1f1;
# }
# #T_2d05e_row16_col3 {
#   background-color: #cde11d;
#   color: #000000;
# }
# #T_2d05e_row17_col0 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_2d05e_row17_col3 {
#   background-color: #efe51c;
#   color: #000000;
# }
# #T_2d05e_row18_col0 {
#   background-color: #2d718e;
#   color: #f1f1f1;
# }
# #T_2d05e_row19_col0 {
#   background-color: #2b758e;
#   color: #f1f1f1;
# }
# #T_2d05e_row20_col0 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_2d05e_row21_col0 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_2d05e_row22_col0 {
#   background-color: #25838e;
#   color: #f1f1f1;
# }
# #T_2d05e_row23_col0 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_2d05e_row24_col0 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_2d05e_row24_col3, #T_2d05e_row25_col3 {
#   background-color: #aadc32;
#   color: #000000;
# }
# #T_2d05e_row25_col0 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_2d05e_row26_col0 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_2d05e_row26_col3, #T_2d05e_row34_col3, #T_2d05e_row35_col3, #T_2d05e_row36_col3 {
#   background-color: #89d548;
#   color: #000000;
# }
# #T_2d05e_row27_col0 {
#   background-color: #1e9d89;
#   color: #f1f1f1;
# }
# #T_2d05e_row28_col0 {
#   background-color: #1fa187;
#   color: #f1f1f1;
# }
# #T_2d05e_row29_col0 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# #T_2d05e_row30_col0 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_2d05e_row30_col3, #T_2d05e_row34_col0 {
#   background-color: #40bd72;
#   color: #f1f1f1;
# }
# #T_2d05e_row31_col0 {
#   background-color: #29af7f;
#   color: #f1f1f1;
# }
# #T_2d05e_row32_col0 {
#   background-color: #31b57b;
#   color: #f1f1f1;
# }
# #T_2d05e_row33_col0 {
#   background-color: #38b977;
#   color: #f1f1f1;
# }
# #T_2d05e_row35_col0 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_2d05e_row36_col0 {
#   background-color: #56c667;
#   color: #000000;
# }
# #T_2d05e_row37_col0 {
#   background-color: #60ca60;
#   color: #000000;
# }
# #T_2d05e_row38_col0 {
#   background-color: #6ccd5a;
#   color: #000000;
# }
# #T_2d05e_row40_col0 {
#   background-color: #84d44b;
#   color: #000000;
# }
# #T_2d05e_row40_col3, #T_2d05e_row49_col3 {
#   background-color: #297b8e;
#   color: #f1f1f1;
# }
# #T_2d05e_row41_col0 {
#   background-color: #93d741;
#   color: #000000;
# }
# #T_2d05e_row41_col2, #T_2d05e_row43_col2, #T_2d05e_row46_col2, #T_2d05e_row49_col2 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_2d05e_row41_col3 {
#   background-color: #24878e;
#   color: #f1f1f1;
# }
# #T_2d05e_row42_col0 {
#   background-color: #a0da39;
#   color: #000000;
# }
# #T_2d05e_row42_col3, #T_2d05e_row43_col3 {
#   background-color: #2e6e8e;
#   color: #f1f1f1;
# }
# #T_2d05e_row43_col0 {
#   background-color: #addc30;
#   color: #000000;
# }
# #T_2d05e_row45_col0 {
#   background-color: #cae11f;
#   color: #000000;
# }
# #T_2d05e_row45_col1 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_2d05e_row46_col0 {
#   background-color: #d8e219;
#   color: #000000;
# }
# #T_2d05e_row47_col0 {
#   background-color: #e5e419;
#   color: #000000;
# }
# #T_2d05e_row48_col0 {
#   backg
